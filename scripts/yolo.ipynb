# %% [markdown]
# Install YOLOv8

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.8 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Train YOLOv8 on staff-tag dataset

# %%
# %cd /content/drive/MyDrive/staff-detection
# !ls data
# Out:
# /content/drive/MyDrive/staff-detection
# data.yaml  images  labels

# %%
# !yolo detect train \
    data=data/data.yaml \
    model=yolov8n.pt \
    imgsz=640 \
    epochs=10 \
    batch=4 \
    name=staff_tag_model
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %% [markdown]
# Test the trained model on MP4

# %%
# !yolo predict \
    model=runs/detect/staff_tag_model7/weights/best.pt \
    source=sample.mp4 \
    save=True \
    name=staff_test_output
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 194.5ms
# video 1/1 (frame 2/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 181.9ms
# video 1/1 (frame 3/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 177.6ms
# video 1/1 (frame 4/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 164.9ms
# video 1/1 (frame 5/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 170.4ms
# video 1/1 (frame 6/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 163.7ms
# video 1/1 (frame 7/1341) /content/drive/MyDrive/staff-detection/sample.mp4: 480x640 (no detections), 163.6ms
# ...
